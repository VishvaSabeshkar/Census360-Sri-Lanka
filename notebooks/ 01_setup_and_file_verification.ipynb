# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.census360_raw;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.census360;

# %%
# %sql
SHOW SCHEMAS IN workspace;

# %%
raw_path = "/Volumes/workspace/default/census360_raw/"

files = dbutils.fs.ls(raw_path)

for f in files:
    print(f.name)

# %%
expected_files = [
    "GN_population_excel.xlsx",
    "GN_housing_excel.xlsx",
    "TRCSL_Telecom_Statistics_Q1_2026.xlsx",
    "GNDList_Final.xlsx",
    "population_by_district_in_census_years.csv",
    "population_2012_2.csv"
]

available_files = [f.name for f in dbutils.fs.ls("/Volumes/workspace/default/census360_raw/")]

missing_files = [file for file in expected_files if file not in available_files]

if len(missing_files) == 0:
    print("All 6 files are visible. Step 1 completed successfully.")
else:
    print("Missing files:")
    for file in missing_files:
        print(file)
